# %%
from transformers import AutoTokenizer, BertForSequenceClassification, Trainer, TrainingArguments, BertConfig, BertTokenizerFast, BertModel

from load_data import *

# %%
dataset = pd.read_csv("/opt/ml/input/data/train/train.tsv", delimiter='\t', header=None)
tokenizer = AutoTokenizer.from_pretrained('facebook/mbart-large-cc25')

# %%
for i in range(10):
    text = dataset[1][i]

    tokenized_text = tokenizer.tokenize(text)

    print(text)
    print(tokenized_text)
    print(tokenizer.decode(tokenizer.encode(text)))
    print()
# Out:
# 영국에서 사용되는 스포츠 유틸리티 자동차의 브랜드로는 랜드로버(Land Rover)와 지프(Jeep)가 있으며, 이 브랜드들은 자동차의 종류를 일컫는 말로 사용되기도 한다.
# ['▁영국', '에서', '▁사용', '되는', '▁스포츠', '▁유', '틸', '리', '티', '▁자동차', '의', '▁브랜드', '로는', '▁', '랜드', '로', '버', '(', 'Land', '▁Rover', ')', '와', '▁지', '프', '(', 'Je', 'ep', ')', '가', '▁있으며', ',', '▁이', '▁브랜드', '들은', '▁자동차', '의', '▁종류', '를', '▁일', '컫', '는', '▁말', '로', '▁사용', '되기', '도', '▁한다', '.']
# 영국에서 사용되는 스포츠 유틸리티 자동차의 브랜드로는 랜드로버(Land Rover)와 지프(Jeep)가 있으며, 이 브랜드들은 자동차의 종류를 일컫는 말로 사용되기도 한다.</s>en_XX
#
# 선거에서 민주당은 해산 전 의석인 230석에 한참 못 미치는 57석(지역구 27석, 비례대표 30석)을 획득하는 데 그쳤다.
# ['▁선거', '에서', '▁민주당', '은', '▁해', '산', '▁전', '▁의', '석', '인', '▁230', '석', '에', '▁한', '참', '▁못', '▁미', '치는', '▁57', '석', '(', '지역', '구', '▁27', '석', ',', '▁비', '례', '대표', '▁30', '석', ')', '을', '▁획득', '하는', '▁데', '▁그', '쳤다', '.']
# 선거에서 민주당은 해산 전 의석인 230석에 한참 못 미치는 57석(지역구 27석, 비례대표 30석)을 획득하는 데 그쳤다.</s>en_XX
#
# 유럽 축구 연맹(UEFA) 집행위원회는 2014년 1월 24일에 열린 회의를 통해 2017년 대회부터 UEFA U-21 축구 선수권 대회 참가국을 8개국에서 12개국으로 확대하기로 결정했다.
# ...

# %%
train_dataset = load_data("/opt/ml/input/data/train/augmented_google.tsv", True)

tokenized_train = tokenized_dataset(train_dataset, tokenizer)

# %%
pd.concat([train_dataset[:8801], train_dataset[9000:]])
# print(train_dataset)
# Out:
#                                                 sentence entity_01  entity_02  \
# 0      영국에서 사용되는 스포츠 유틸리티 자동차의 브랜드로는 랜드로버(Land Rover)...      랜드로버        자동차
# 1      선거에서 민주당은 해산 전 의석인 230석에 한참 못 미치는 57석(지역구 27석 ...       민주당        27석
# 2      유럽 축구 연맹(UEFA) 집행위원회는 2014년 1월 24일에 열린 회의를 통해 ...  유럽 축구 연맹       UEFA
# 3      용병 공격수 챠디의 부진과 시즌 초 활약한 강수일의 침체 시즌 중반에 영입한 세르비...       강수일        공격수
# 4      람캄행 왕은 1237년에서 1247년 사이 수코타이의 왕 퍼쿤 씨 인트라팃과 쓰엉 ...       람캄행  퍼쿤 씨 인트라팃
# ...                                                  ...       ...        ...
# 14608  13 일 강진군 산악회 (회장 황용 이순신)은 겨울이며 이웃은 힘의 근처에 살기 어...   강진군 산악회         회장
# 14609  2002년 FIFA 월드컵 사우디아라비아의 첫 번째 다리에서 독일 80 원이었고 네...   사우디아라비아      2002년
# 14610  일본의 두 메이커 토요타 및 닛산은 시장 점유율을 높이기 위해 새로운 자동차를 개발...       토요타         일본
# 14611  LG전자은 올해 국내 시장에서 2020 LG 그램 시리즈를 이번 달부터 일련의 북미...      LG전자         북미
# 14612  전남 지방 의회 안전 건설 소방위원회 차영수 의원 (강진 1) 따뜻한 휴가 분위기를...       차영수         의원
#
#        label
# 0         17
# ...
